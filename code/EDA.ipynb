# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot

# %%
df_sp500_prices = pd.read_csv("/Users/jojoli/Documents/CMU/Sophomore/S26/citadel_datathon/coding/citadel-women-datathon-2026/dataset/Stock Data/sp500_prices_all_since_2015.csv")
df_aiAdoption = pd.read_csv("/Users/jojoli/Documents/CMU/Sophomore/S26/citadel_datathon/coding/citadel-women-datathon-2026/dataset/Gen AI/enterprise_ai_adoption_internet_events.csv")

# %%
df_aiAdoption.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ticker            1070 non-null   object
#  1   company_name      1070 non-null   object
#  2   industry          1070 non-null   object
#  3   use_case          1070 non-null   object
#  4   agent_type        1070 non-null   object
#  5   agent_use_case    1070 non-null   object
#  6   ai_vendor         691 non-null    object
#  7   ai_model          192 non-null    object
#  8   annoucement_date  985 non-null    object
#  9   source_url        1070 non-null   object
#  10  sp_index          1070 non-null   int64
# dtypes: int64(1), object(10)
# memory usage: 92.1+ KB

# %%
df_sp500_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1351067 entries, 0 to 1351066
# Data columns (total 10 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Date          1351067 non-null  object
#  1   Open          1351067 non-null  float64
#  2   High          1351067 non-null  float64
#  3   Low           1351067 non-null  float64
#  4   Close         1351067 non-null  float64
#  5   Adj Close     1351067 non-null  float64
#  6   Volume        1351067 non-null  int64
#  7   Dividends     1351067 non-null  float64
#  8   Stock Splits  1351067 non-null  float64
#  9   ticker        1351067 non-null  object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 103.1+ MB

# %%
df_sp500_prices.head(-10)
# Out:
#                Date        Open        High         Low       Close  \
# 0        2015-01-02   41.180000   41.310001   40.369999   40.560001
# 1        2015-01-05   40.320000   40.459999   39.700001   39.799999
# 2        2015-01-06   39.810001   40.020000   39.020000   39.180000
# 3        2015-01-07   39.520000   39.810001   39.290001   39.700001
# 4        2015-01-08   40.240002   40.980000   40.180000   40.889999
# ...             ...         ...         ...         ...         ...
# 1351052  2026-01-07  129.490005  130.229996  125.639999  125.669998
# 1351053  2026-01-08  124.839996  128.339996  124.550003  126.849998
# 1351054  2026-01-09  127.680000  128.350006  126.080002  127.169998
# 1351055  2026-01-12  126.980003  127.269997  124.199997  125.320000
# 1351056  2026-01-13  125.959999  125.970001  123.320000  124.620003
#
#           Adj Close   Volume  Dividends  Stock Splits ticker
# 0         37.054726  1529200        0.1           0.0      A
# ...

# %%
rand_5_companies = np.random.choice(df_sp500_prices['ticker'].unique(), 10)

# %%
plt.clf()
apple_stocks = df_sp500_prices[df_sp500_prices['ticker'] == 'AAPL']
google_stocks = df_sp500_prices[df_sp500_prices['ticker'] == 'GOOGL']
for comp in rand_5_companies:
    stocks = df_sp500_prices[df_sp500_prices['ticker'] == comp]
    big_release_stock = stocks[stocks.apply(lambda r: r.str.contains('2024-02').any(), axis=1)]
    open_prices = big_release_stock['Open']
    high_prices = big_release_stock['High']
    low_prices = big_release_stock['Low']
    dates = big_release_stock['Date']
    scatter = sns.lineplot(x = dates, y = open_prices)
    # plt.savefig("out" + comp + ".png")
plt.show()

# %%
open_prices = apple_2022['Open']
high_prices = apple_2022['High']
low_prices = apple_2022['Low']
dates = apple_2022['Date']
sns.scatterplot(x = dates, y = open_prices)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
open_prices = google_2022['Open']
high_prices = google_2022['High']
low_prices = google_2022['Low']
dates = google_2022['Date']
sns.scatterplot(x = dates, y = open_prices)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
df4[df4['total'] > 200].total.count()

# %%
sns.distplot(df4["total"], kde=True)

# %%
df4.columns

# %%
#DF4=df4[['total', 'industry', 'implied_cash_per_share']]
sns.heatmap(df4.corr(), cmap="YlGnBu", fmt = ".2f")

# %%
sns.scatterplot(x="implied_cash_per_share", y="var 2", data=df4)
